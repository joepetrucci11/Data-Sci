# %% [markdown]
# <a href="https://colab.research.google.com/github/joepetrucci11/Data-Sci/blob/main/Joseph_Petrucci_lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # this is a set of tools 
import matplotlib.pyplot as plt  # this is a set of tools 
import pandas as pd  # this is a set of tools 
import urllib.request  # this is a set of tools

# %%
url = "https://raw.githubusercontent.com/RahulSHJsingh/Data-Science/main/cereal_data.csv" # this is a url

# %%
urllib.request.urlretrieve(url,'cereal_data.csv') # this gets the database
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f144ef7f940>)

# %%
cereal_data = pd.read_csv('cereal_data.csv') # this assigns it to the variable cereal data

# %%
cereal_data # this displays what cereal data has
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_data["sugars"] # this filters by sugars
# Out:
# 0      6
# 1      8
# 2      5
# 3      0
# 4      8
#       ..
# 72     3
# 73    12
# 74     3
# 75     3
# 76     8
# Name: sugars, Length: 77, dtype: int64

# %%
cereal_data[["calories", "sugars"]] # this filters by calories and sugars
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
cereal_data["sugars"].mean() # this finds the mean of sugars
# Out:
# 6.922077922077922

# %%
cereal_data[["calories", "sugars"]].mean() # this finds the mean of calories and sugars
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe() # this describes the data in cereal data
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.')  # this plots a graph

# %%
x = cereal_data[["sugars"]] # this is just another way of plotting a graph. # this gives you the x axis 
y = cereal_data[["calories"]] # this gives you the y axis 

plt.plot(x,y,'.') # this plots the graph

# %%
x = cereal_data[["sugars"]] # this is just another way of doing it. # this gives you the x axis 
y = cereal_data[["calories"]] # this gives you the y axis 

plt.plot(x,y,'.') # this plots the graph 
plt.xlabel("sugars") # this labels the x axis 
plt.ylabel("calories") # this labels the y axis 
plt.title("sugars vs calories") # this gives the graph a title
# Out:
# Text(0.5, 1.0, 'sugars vs calories')

# %%
x = cereal_data[["protein"]] # this is just another way of doing it. # this gives you the x axis 
y = cereal_data[["fat"]]  # this gives you the y axis 

plt.plot(x,y,'.') # this plots the graph  
plt.xlabel("protein")  # this labels the x axis 
plt.ylabel("fat") # this labels the y axis 
plt.title("protein vs fat")  # this gives the graph a title
# Out:
# Text(0.5, 1.0, 'protein vs fat')

# %%
x = cereal_data[["sugars"]]  # this gives you the x axis 
y = cereal_data[["rating"]]  # this gives you the y axis

# %%
from sklearn.linear_model import LinearRegression # this is a set of tools
linear_regressor = LinearRegression() # this gives you the linear regression

# %%
linear_regressor.fit(x, y) # this gives you the linear regression for the data set
y_pred = linear_regressor.predict(x) # this the prediction for the y

# %%
plt.plot(x, y,'.') # this plots the graph 
plt.plot(x, y_pred, color='c') # this plots the y prediction
plt.show() # this shows the graph

# %%
X = np.linspace(0,10,50) # this gives you 50 numbers between 0 and 10

# %%
X # this shows what array X holds
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
m = 3 # this assigns 3 to m 
b = 7 # this assigns 7 to b

y = m * X + b # this is the equation of a line

# %%
plt.plot(X,y,'.') # this plots the graph

# %%
noise = 10 * np.random.randn(50) # this is meant to offset the data

# %%
y = m * X + b + noise # synythetic data set

# %%
plt.plot(X,y,'.') # this plots the graph

# %%
m_guess = 1 # this assigns 1 to m guess 
b_guess = 1 # this assigns 1 to b guess

y_guess = m_guess * X + b_guess # this assigns the reult of the formula to y guess 

plt.plot(X,y_guess,'r.'); # this plots the prediction graph 
plt.plot(X,y,'g.') # this plots the graph

# %%
m_guess = 5 # this assigns 5 to m guess 
b_guess = 15 # this assigns 15 to b guess 

y_guess = m_guess * X + b_guess # this assigns the reult of the formula to y guess 

plt.plot(X,y_guess,'r.'); # this plots the prediction graph 
plt.plot(X,y,'g.') # this plots the graph

# %%
m_guess = 3.5 # this assigns 3.5 to m guess 
b_guess = 5 # this assigns 5 to b guess 

y_guess = m_guess * X + b_guess # this assigns the reult of the formula to y guess 

plt.plot(X,y_guess,'r.'); # this plots the prediction graph 
plt.plot(X,y,'g.') # this plots the graph

# %%
loss = np.sum((y_guess - y)**2) # this calculates the loss

# %%
loss # this displays the loss
# Out:
# 4456.945054684344

# %%
m_guess = 3 # this assigns 3 to m guess 
b_guess = 7 # this assigns 7 to b guess  

y_guess = m_guess * X + b_guess # this assigns the reult of the formula to y guess 

plt.plot(X,y_guess,'r.'); # this plots the prediction graph 
plt.plot(X,y,'g.') # this plots the graph

# %%
for m_guess in np.linspace(-10,10,10): # this is a for loop
  print(m_guess) # this prints the m guess
# Out:
# -10.0
# -7.777777777777778
# -5.555555555555555
# -3.333333333333333
# -1.1111111111111107
# 1.1111111111111107
# 3.333333333333334
# 5.555555555555557
# 7.777777777777779
# 10.0

# %%
for m_guess in np.linspace(-10,10,10): # this is a for loop
  for b_guess in np.linspace(-10,10,10): # this is a for loop

    y_guess = m_guess * X + b_guess # this assigns the reult of the formula to y guess

    plt.plot(X,y_guess,'r.'); # this plots the prediction graph 
    plt.plot(X,y,'g.'); # this plots the graph 
    plt.show() # this shows the graph 

    loss = np.sum((y_guess - y)**2) # this calculates the loss 

    print(loss,m_guess,b_guess) # this prints the loss, m guess and b guess
# Out:
# 409798.27116771386 -10.0 -10.0
# 391878.637344613 -10.0 -7.777777777777778
# 374452.8306820061 -10.0 -5.555555555555555
# 357520.851179893 -10.0 -3.333333333333333
# 341082.6988382736 -10.0 -1.1111111111111107
# 325138.37365714816 -10.0 1.1111111111111107
# 309687.8756365165 -10.0 3.333333333333334
# 294731.20477637864 -10.0 5.555555555555557
# 280268.36107673467 -10.0 7.777777777777779
# 266299.34453758446 -10.0 10.0
# 302546.1860887479 -7.777777777777778 -10.0
# 287095.6880681162 -7.777777777777778 -7.777777777777778
# 272139.01720797835 -7.777777777777778 -5.555555555555555
# 257676.17350833435 -7.777777777777778 -3.333333333333333
# 243707.1569691842 -7.777777777777778 -1.1111111111111107
# 230231.96759052787 -7.777777777777778 1.1111111111111107
# 217250.6053723653 -7.777777777777778 3.333333333333334
# 204763.0703146966 -7.777777777777778 5.555555555555557
# 192769.36241752177 -7.777777777777778 7.777777777777779
# 181269.48168084075 -7.777777777777778 10.0
# ...

# %%
best_loss = 100000 # this assigns 10000 to the best loss
best_m = 0 # this assigns 0 to best m 
best_b = 0 # this assigns 0 to best b 

for m_guess in np.linspace(-10,10,20): # the 20 gives us more fine grain guesses
    for b_guess in np.linspace(-10,10,20): # this is a for loop 
        
        y_guess = m_guess * X + b_guess # this assigns the result of the formula to y guess

        loss = np.sum((y_guess - y)**2) # this calculates the loss 

        if loss < best_loss: # this is a nested if then else statement 
            
            best_loss = loss # this is the result of the condition being true 
            best_m = m_guess # this is the result of the condition being true 
            best_b = b_guess # this is the result of the condition being true 

            plt.plot(X,y_guess,'r.'); # this plots the prediction graph 
            plt.plot(X,y,'g.'); # this plots the graph 
            plt.show() # this shows the graph 

            print(loss,m_guess,b_guess) # this prints loss, m guess and b guess
# Out:
# 99541.22161761663 -4.736842105263158 7.894736842105264
# 95645.1562271112 -4.736842105263158 8.94736842105263
# 91859.89416070552 -4.736842105263158 10.0
# 89214.92364866864 -3.6842105263157894 3.6842105263157894
# 85429.66158226295 -3.6842105263157894 4.7368421052631575
# 81755.20283995695 -3.6842105263157894 5.789473684210526
# 78191.5474217507 -3.6842105263157894 6.842105263157894
# 74738.69532764418 -3.6842105263157894 7.894736842105264
# 71396.64655763737 -3.6842105263157894 8.94736842105263
# 68165.40111173029 -3.6842105263157894 10.0
# 65927.46321883528 -2.6315789473684212 3.6842105263157894
# 62696.21777292819 -2.6315789473684212 4.7368421052631575
# 59575.775651120835 -2.6315789473684212 5.789473684210526
# 56566.1368534132 -2.6315789473684212 6.842105263157894
# 53667.30137980528 -2.6315789473684212 7.894736842105264
# 50879.2692302971 -2.6315789473684212 8.94736842105263
# 48202.04040488861 -2.6315789473684212 10.0
# 46371.13513113545 -1.578947368421053 3.6842105263157894
# ...
